# %% [markdown]
# <a href="https://colab.research.google.com/github/lubaochuan/ml_python/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
age = 40

# %%
age

# %% [markdown]
# Three types of values in Python: numbers, strings, and booleans.

# %%
age = 50
temp = 35.8
name = 'Eureka'
is_offline = False

# %%
type(age)
# Out:
# int

# %%
type(temp)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(is_offline)
# Out:
# bool
