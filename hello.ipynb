# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lubaochuan/ml_python/blob/main/hello.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# Hello world!

# %%
print("Hello world!")
# Out:
# Hello world!
